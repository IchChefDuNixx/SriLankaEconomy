# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
basedir = '../../data/gdp/'
data = pd.read_csv(f'{basedir}API_LKA_DS2_en_csv_v2_21470.csv')
kaggle = pd.read_csv(f'{basedir}Sri Lanka Economy.csv')
data.drop(columns=[data.columns[1], data.columns[3],data.columns[0], 'Unnamed: 68'], inplace=True)

# %%
DEUTSCHLAND = pd.read_csv(f'{basedir}API_DEU_DS2_en_csv_v2_15903.csv', sep=',')
DEUTSCHLAND.drop(columns=[DEUTSCHLAND.columns[1], DEUTSCHLAND.columns[3],DEUTSCHLAND.columns[0], 'Unnamed: 68'], inplace=True)
DEUTSCHLAND
# Out:
#                                          Indicator Name  1960        1961  \
# 0        Intentional homicides, male (per 100,000 male)   NaN         NaN
# 1     Internally displaced persons, new displacement...   NaN         NaN
# 2     Voice and Accountability: Percentile Rank, Low...   NaN         NaN
# 3     Travel services (% of commercial service exports)   NaN         NaN
# 4              Commercial service exports (current US$)   NaN         NaN
# ...                                                 ...   ...         ...
# 1491       Average precipitation in depth (mm per year)   NaN  700.000000
# 1492  Land area where elevation is below 5 meters (%...   NaN         NaN
# 1493  Rural land area where elevation is below 5 met...   NaN         NaN
# 1494                  Arable land (hectares per person)   NaN    0.166536
# 1495  Fertilizer consumption (kilograms per hectare ...   NaN  268.068740
#
#             1962        1963        1964        1965        1966        1967  \
# ...

# %%
# Filter the DataFrame
df_filtered = DEUTSCHLAND[DEUTSCHLAND['Indicator Name'].str.contains('GDP', case=False, na=False)]

# Transpose
df_transposed = df_filtered.T.copy()

# Use the first row of the transposed DataFrame as the header
df_transposed.columns = df_transposed.iloc[0]
df_transposed = df_transposed.drop(df_transposed.index[0])
df_DEUTSCHLAND = df_transposed[40:][['GDP (current US$)', 'Central government debt, total (% of GDP)',  'Industry (including construction), value added (% of GDP)', 'Agriculture, forestry, and fishing, value added (% of GDP)', 'Services, value added (% of GDP)', 'Military expenditure (% of GDP)', 'GDP per capita (current US$)']]

# Display the cleaned DataFrame
df_DEUTSCHLAND
# Out:
# Indicator Name     GDP (current US$)  \
# 2000            1966980701145.100098
# 2001             1966381496641.72998
# 2002            2102350798305.889893
# 2003            2534715518349.009766
# 2004            2852317768061.779785
# 2005            2893393187361.870117
# 2006            3046308753670.580078
# 2007            3484056680854.910156
# 2008                 3808786022312.5
# 2009            3479800820863.279785
# 2010            3468154343000.009766
# 2011            3824828563521.410156
# 2012            3597896500945.310059
# 2013            3808086291482.359863
# 2014            3965800686309.790039
# 2015            3423568450957.029785
# 2016            3537784107980.549805
# 2017            3763092263752.950195
# 2018            4052008447223.529785
# 2019            3957208055215.680176
# 2020            3940142541354.100098
# 2021            4348297440387.529785
# 2022            4163596357879.390137
# 2023            4525703903627.530273
#
# ...

# %%
kaggle=kaggle[['Year','GDP Per Capita']]

# %%
kaggle
# Out:
#     Year GDP Per Capita
# 0   2021         $3,815
# 1   2020         $3,694
# 2   2019         $3,848
# 3   2018         $4,059
# 4   2017         $4,077
# ..   ...            ...
# 57  1964           $121
# 58  1963           $117
# 59  1962           $139
# 60  1961           $143
# 61  1960           $143
#
# [62 rows x 2 columns]

# %%
# Filter the DataFrame
df_filtered = data[data['Indicator Name'].str.contains('GDP', case=False, na=False)]

# Transpose
df_transposed = df_filtered.T

# Use the first row of the transposed DataFrame as the header
df_transposed.columns = df_transposed.iloc[0]
df_transposed = df_transposed.drop(df_transposed.index[0])
df_transposed = df_transposed[40:][['GDP (current US$)', 'Central government debt, total (% of GDP)',  'Industry (including construction), value added (% of GDP)', 'Agriculture, forestry, and fishing, value added (% of GDP)', 'Services, value added (% of GDP)', 'Military expenditure (% of GDP)']]

# %%
df_transposed
# Out:
# Indicator Name   GDP (current US$) Central government debt, total (% of GDP)  \
# 2000            16330814179.976601                                 96.904033
# 2001              15749753804.8344                                103.219274
# 2002            16536535647.083401                                105.524991
# 2003            18881765437.215099                                102.270712
# 2004              20662525941.2985                                102.328537
# 2005              24405791044.7761                                 90.604913
# 2006            28279802405.913799                                 88.699484
# 2007            32350238760.423901                                 84.994417
# 2008              40713826215.0093                                       NaN
# 2009              42066224093.0065                                 86.063492
# 2010            58636161081.711998                                 69.253025
# ...

# %%
# 1. Make sure both DataFrames have a 'Year' column of the same type (e.g. int).
df_transposed['Year'] = df_transposed.index.astype(int)
kaggle['Year'] = kaggle['Year'].astype(int)

# 2. Perform the left join on 'Year'.
df_merged = pd.merge(df_transposed, kaggle, on='Year', how='left')

# 3. Take a quick look
df_merged
# Out:
#      GDP (current US$) Central government debt, total (% of GDP)  \
# 0   16330814179.976601                                 96.904033
# 1     15749753804.8344                                103.219274
# 2   16536535647.083401                                105.524991
# 3   18881765437.215099                                102.270712
# 4     20662525941.2985                                102.328537
# 5     24405791044.7761                                 90.604913
# 6   28279802405.913799                                 88.699484
# 7   32350238760.423901                                 84.994417
# 8     40713826215.0093                                       NaN
# 9     42066224093.0065                                 86.063492
# 10  58636161081.711998                                 69.253025
# 11    67753284043.9282                                 68.525739
# 12  70447216891.336594                                 66.747235
# ...

# %%
df_merged.set_index('Year', inplace=True)
df_merged
# Out:
#        GDP (current US$) Central government debt, total (% of GDP)  \
# Year
# 2000  16330814179.976601                                 96.904033
# 2001    15749753804.8344                                103.219274
# 2002  16536535647.083401                                105.524991
# 2003  18881765437.215099                                102.270712
# 2004    20662525941.2985                                102.328537
# 2005    24405791044.7761                                 90.604913
# 2006  28279802405.913799                                 88.699484
# 2007  32350238760.423901                                 84.994417
# 2008    40713826215.0093                                       NaN
# 2009    42066224093.0065                                 86.063492
# 2010  58636161081.711998                                 69.253025
# 2011    67753284043.9282                                 68.525739
# 2012  70447216891.336594                                 66.747235
# ...

# %%
df_merged.loc[2023, 'GDP Per Capita'] = "$3,828"
df_merged.loc[2022, 'GDP Per Capita'] = "$3,343"

df_merged.loc[2023, 'Central government debt, total (% of GDP)'] = 103.9
df_merged.loc[2022, 'Central government debt, total (% of GDP)'] = 114.2
df_merged.loc[2021, 'Central government debt, total (% of GDP)'] = 100.0
df_merged.loc[2020, 'Central government debt, total (% of GDP)'] = 96.6
df_merged.loc[2019, 'Central government debt, total (% of GDP)'] = 81.9
df_merged.loc[2018, 'Central government debt, total (% of GDP)'] = 78.4
df_merged.loc[2017, 'Central government debt, total (% of GDP)'] = 72.2
df_merged.loc[2008, 'Central government debt, total (% of GDP)'] = 81.5
df_merged.loc[2008, 'Central government debt, total (% of GDP)'] = 79.0

df_merged.loc[2023, 'Military expenditure (% of GDP)'] = 1.386

df_merged
# Out:
#        GDP (current US$) Central government debt, total (% of GDP)  \
# Year
# 2000  16330814179.976601                                 96.904033
# 2001    15749753804.8344                                103.219274
# 2002  16536535647.083401                                105.524991
# 2003  18881765437.215099                                102.270712
# 2004    20662525941.2985                                102.328537
# 2005    24405791044.7761                                 90.604913
# 2006  28279802405.913799                                 88.699484
# 2007  32350238760.423901                                 84.994417
# 2008    40713826215.0093                                      79.0
# 2009    42066224093.0065                                 86.063492
# 2010  58636161081.711998                                 69.253025
# 2011    67753284043.9282                                 68.525739
# 2012  70447216891.336594                                 66.747235
# ...

# %%
df_DEUTSCHLAND.loc[2023, 'Central government debt, total (% of GDP)'] = 62.9
df_DEUTSCHLAND.loc[2022, 'Central government debt, total (% of GDP)'] = 65.0
df_DEUTSCHLAND.loc[2021, 'Central government debt, total (% of GDP)'] = 68.1
df_DEUTSCHLAND.loc[2020, 'Central government debt, total (% of GDP)'] = 68.0
df_DEUTSCHLAND.loc[2019, 'Central government debt, total (% of GDP)'] = 58.7
df_DEUTSCHLAND.loc[2018, 'Central government debt, total (% of GDP)'] = 60.8
df_DEUTSCHLAND.loc[2017, 'Central government debt, total (% of GDP)'] = 64.0
df_DEUTSCHLAND.loc[2016, 'Central government debt, total (% of GDP)'] = 68.3
df_DEUTSCHLAND.loc[2015, 'Central government debt, total (% of GDP)'] = 71.2
df_DEUTSCHLAND.loc[2014, 'Central government debt, total (% of GDP)'] = 74.5
df_DEUTSCHLAND.loc[2013, 'Central government debt, total (% of GDP)'] = 78.3
df_DEUTSCHLAND.loc[2012, 'Central government debt, total (% of GDP)'] = 80.7
df_DEUTSCHLAND.loc[2011, 'Central government debt, total (% of GDP)'] = 79.4
df_DEUTSCHLAND.loc[2010, 'Central government debt, total (% of GDP)'] = 82.0
df_DEUTSCHLAND.loc[2009, 'Central government debt, total (% of GDP)'] = 73.2
df_DEUTSCHLAND.loc[2008, 'Central government debt, total (% of GDP)'] = 65.7
df_DEUTSCHLAND.loc[2007, 'Central government debt, total (% of GDP)'] = 64.2
df_DEUTSCHLAND.loc[2006, 'Central government debt, total (% of GDP)'] = 66.9
df_DEUTSCHLAND.loc[2005, 'Central government debt, total (% of GDP)'] = 67.5
df_DEUTSCHLAND.loc[2004, 'Central government debt, total (% of GDP)'] = 65.2
df_DEUTSCHLAND.loc[2003, 'Central government debt, total (% of GDP)'] = 63.5
df_DEUTSCHLAND.loc[2002, 'Central government debt, total (% of GDP)'] = 59.9
df_DEUTSCHLAND.loc[2001, 'Central government debt, total (% of GDP)'] = 58.2
df_DEUTSCHLAND.loc[2000, 'Central government debt, total (% of GDP)'] = 59.3
df_DEUTSCHLAND.loc[2023, 'Military expenditure (% of GDP)'] = 1.5
df_DEUTSCHLAND
# Out:
#       GDP (current US$)  Central government debt, total (% of GDP)  \
# Year
# 2000       1.966981e+12                                       59.3
# 2001       1.966381e+12                                       58.2
# 2002       2.102351e+12                                       59.9
# 2003       2.534716e+12                                       63.5
# 2004       2.852318e+12                                       65.2
# 2005       2.893393e+12                                       67.5
# 2006       3.046309e+12                                       66.9
# 2007       3.484057e+12                                       64.2
# 2008       3.808786e+12                                       65.7
# 2009       3.479801e+12                                       73.2
# 2010       3.468154e+12                                       82.0
# 2011       3.824829e+12                                       79.4
# 2012       3.597897e+12                                       80.7
# ...

# %%
# Assign 'Central government debt, total (% of GDP)' values
debt_values = {
    2023: 62.9, 2022: 65.0, 2021: 68.1, 2020: 68.0, 2019: 58.7,
    2018: 60.8, 2017: 64.0, 2016: 68.3, 2015: 71.2, 2014: 74.5,
    2013: 78.3, 2012: 80.7, 2011: 79.4, 2010: 82.0, 2009: 73.2,
    2008: 65.7, 2007: 64.2, 2006: 66.9, 2005: 67.5, 2004: 65.2,
    2003: 63.5, 2002: 59.9, 2001: 58.2, 2000: 59.3
}

# Update the values in the DataFrame
for year, value in debt_values.items():
    df_DEUTSCHLAND.loc[year, 'Central government debt, total (% of GDP)'] = value

# Assign 'Military expenditure (% of GDP)' for 2023
df_DEUTSCHLAND.loc[2023, 'Military expenditure (% of GDP)'] = 1.5

# Display the updated DataFrame
df_DEUTSCHLAND
# Out:
# Indicator Name     GDP (current US$)  \
# 2000            1966980701145.100098
# 2001             1966381496641.72998
# 2002            2102350798305.889893
# 2003            2534715518349.009766
# 2004            2852317768061.779785
# 2005            2893393187361.870117
# 2006            3046308753670.580078
# 2007            3484056680854.910156
# 2008                 3808786022312.5
# 2009            3479800820863.279785
# 2010            3468154343000.009766
# 2011            3824828563521.410156
# 2012            3597896500945.310059
# 2013            3808086291482.359863
# 2014            3965800686309.790039
# 2015            3423568450957.029785
# 2016            3537784107980.549805
# 2017            3763092263752.950195
# 2018            4052008447223.529785
# 2019            3957208055215.680176
# 2020            3940142541354.100098
# 2021            4348297440387.529785
# 2022            4163596357879.390137
# 2023            4525703903627.530273
# ...

# %%
df_DEUTSCHLAND.set_index('Year', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10952\2033565884.py in ?()
# ----> 1 df_DEUTSCHLAND.set_index('Year', inplace=True)
#
# ~\anaconda3\envs\vis24\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Year'] are in the columns"

# %%
df_DEUTSCHLAND.to_csv('de.csv')
df_merged.to_csv('sl.csv')

# %%
df_DEUTSCHLAND = pd.read_csv('de.csv')
df_DEUTSCHLAND.rename(columns={"Unnamed: 0": "Year"}, inplace=True)
df_DEUTSCHLAND
# Out:
#     Year  GDP (current US$)  Central government debt, total (% of GDP)  \
# 0   2000       1.966981e+12                                        NaN
# 1   2001       1.966381e+12                                        NaN
# 2   2002       2.102351e+12                                        NaN
# 3   2003       2.534716e+12                                        NaN
# 4   2004       2.852318e+12                                        NaN
# 5   2005       2.893393e+12                                        NaN
# 6   2006       3.046309e+12                                        NaN
# 7   2007       3.484057e+12                                        NaN
# 8   2008       3.808786e+12                                        NaN
# 9   2009       3.479801e+12                                        NaN
# 10  2010       3.468154e+12                                        NaN
# 11  2011       3.824829e+12                                        NaN
# ...

# %%
df_DEUTSCHLAND.set_index('Year', inplace=True)
df_DEUTSCHLAND
# Out:
#       GDP (current US$)  Central government debt, total (% of GDP)  \
# Year
# 2000       1.966981e+12                                        NaN
# 2001       1.966381e+12                                        NaN
# 2002       2.102351e+12                                        NaN
# 2003       2.534716e+12                                        NaN
# 2004       2.852318e+12                                        NaN
# 2005       2.893393e+12                                        NaN
# 2006       3.046309e+12                                        NaN
# 2007       3.484057e+12                                        NaN
# 2008       3.808786e+12                                        NaN
# 2009       3.479801e+12                                        NaN
# 2010       3.468154e+12                                        NaN
# 2011       3.824829e+12                                        NaN
# 2012       3.597897e+12                                        NaN
# ...

# %%
df_DEUTSCHLAND
# Out:
#       GDP (current US$)  Central government debt, total (% of GDP)  \
# Year
# 2000       1.966981e+12                                       59.3
# 2001       1.966381e+12                                       58.2
# 2002       2.102351e+12                                       59.9
# 2003       2.534716e+12                                       63.5
# 2004       2.852318e+12                                       65.2
# 2005       2.893393e+12                                       67.5
# 2006       3.046309e+12                                       66.9
# 2007       3.484057e+12                                       64.2
# 2008       3.808786e+12                                       65.7
# 2009       3.479801e+12                                       73.2
# 2010       3.468154e+12                                       82.0
# 2011       3.824829e+12                                       79.4
# 2012       3.597897e+12                                       80.7
# ...

# %%
df_merged
# Out:
#        GDP (current US$) Central government debt, total (% of GDP)  \
# Year
# 2000  16330814179.976601                                 96.904033
# 2001    15749753804.8344                                103.219274
# 2002  16536535647.083401                                105.524991
# 2003  18881765437.215099                                102.270712
# 2004    20662525941.2985                                102.328537
# 2005    24405791044.7761                                 90.604913
# 2006  28279802405.913799                                 88.699484
# 2007  32350238760.423901                                 84.994417
# 2008    40713826215.0093                                      79.0
# 2009    42066224093.0065                                 86.063492
# 2010  58636161081.711998                                 69.253025
# 2011    67753284043.9282                                 68.525739
# 2012  70447216891.336594                                 66.747235
# ...
